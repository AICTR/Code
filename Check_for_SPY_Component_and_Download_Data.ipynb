# %%
import numpy as np
import pandas as pd
from tools import DownloadData
import json
import yfinance as yf
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
with open("sp500-historical-components.json",'r') as load_f:
    load_dict = json.load(load_f)

# %%
d = {}
for i in load_dict:
    if i['Date'] == '2017/05/03':
        continue
    j = i['Date'].replace('/','-')
    d[j] = i['Symbols']

# %%
tmp = list(d.keys())
tmp.sort()
tmp
# Out:
# ['2008-01-31',
#  '2008-02-29',
#  '2008-03-31',
#  '2008-04-30',
#  '2008-05-30',
#  '2008-06-30',
#  '2008-07-31',
#  '2008-08-29',
#  '2008-09-30',
#  '2008-10-31',
#  '2008-11-28',
#  '2008-12-31',
#  '2009-01-30',
#  '2009-02-27',
#  '2009-03-31',
#  '2009-04-30',
#  '2009-05-29',
#  '2009-06-30',
#  '2009-07-31',
#  '2009-08-31',
#  '2009-09-30',
#  '2009-10-30',
#  '2009-11-30',
#  '2009-12-31',
#  '2010-01-29',
#  '2010-02-26',
#  '2010-03-31',
#  '2010-04-30',
#  '2010-05-28',
#  '2010-06-30',
#  '2010-07-30',
#  '2010-08-31',
#  '2010-09-30',
#  '2010-10-29',
#  '2010-11-30',
#  '2010-12-31',
#  '2011-01-31',
#  '2011-02-28',
#  '2011-03-31',
#  '2011-04-29',
#  '2011-05-31',
#  '2011-06-30',
#  '2011-07-29',
#  '2011-08-31',
#  '2011-09-30',
#  '2011-10-31',
#  '2011-11-30',
#  '2011-12-30',
#  '2012-01-31',
#  '2012-02-29',
#  '2012-03-30',
#  '2012-04-30',
#  '2012-05-31',
#  '2012-06-29',
#  '2012-07-31',
#  '2012-08-31',
#  '2012-09-28',
#  '2012-10-31',
#  '2012-11-30',
#  '2012-12-31',
#  '2013-01-31',
#  '2013-02-28',
#  '2013-03-28',
#  '2013-04-30',
#  '2013-05-31',
#  '2013-06-28',
#  '2013-07-31',
#  '2013-08-30',
#  '2013-09-30',
#  '2013-10-31',
#  '2013-11-29',
#  '2013-12-31',
#  '2014-01-31',
#  '2014-02-28',
#  '2014-03-31',
#  '2014-04-30',
#  '2014-05-30',
#  '2014-06-30',
#  '2014-07-31',
#  '2014-08-29',
#  '2014-09-30',
#  '2014-10-31',
#  '2014-11-28',
#  '2014-12-31',
#  '2015-01-30',
#  '2015-02-27',
#  '2015-03-31',
#  '2015-04-30',
#  '2015-05-29',
#  '2015-06-30',
#  '2015-07-31',
#  '2015-08-31',
#  '2015-09-30',
#  '2015-10-30',
#  '2015-11-30',
#  '2015-12-31',
#  '2016-01-29',
#  '2016-02-29',
#  '2016-03-31',
#  '2016-04-29',
#  '2016-05-31',
#  '2016-06-30',
#  '2016-07-29',
#  '2016-08-31',
#  '2016-09-30',
#  '2016-10-31',
#  '2016-11-30',
#  '2016-12-30',
#  '2017-01-31',
#  '2017-02-28',
#  '2017-03-31',
#  '2017-04-28']

# %%
dd = set()
for i,v in d.items():
    dd = dd.union(set(v))
dd = list(dd)

# %%
dd[:10]
# Out:
# ['AXP', 'AGN', 'CRM', 'TEX', 'CAT', 'ARE', 'AEE', 'SLG', 'MTB', 'MXA']

# %%
DownloadData(d, '2007-01-01','2019-08-31','data/')
# Out:
# Exception in thread Thread-120:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-01-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-117:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-08-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-116:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-10-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-121:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-06-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-118:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2016-11-30', 'No data found, symbol may be delisted')
# Exception in thread Thread-119:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-03-30', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-122:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2009-04-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-124:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-07-30', 'No data found, symbol may be delisted')
# Exception in thread Thread-123:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-01-31', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-125:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2009-06-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-126:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-02-28', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-127:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2016-12-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-130:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2009-07-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-129:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-08-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-128:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2014-03-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-131:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-07-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-132:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-01-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-133:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2014-08-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-134:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-08-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-135:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-01-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-136:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-02-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-137:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-07-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-138:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-11-30', 'No data found, symbol may be delisted')
# Exception in thread Thread-139:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2008-12-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-140:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2016-08-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-141:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-09-28', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-143:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-11-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-142:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-05-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-146:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-04-29', 'No data found, symbol may be delisted')
# Exception in thread Thread-144:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2009-05-29', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-145:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-10-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-147:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-04-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-148:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-11-30', 'No data found, symbol may be delisted')
# Exception in thread Thread-149:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2015-03-31', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-150:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-09-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-151:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-09-30', 'No data found, symbol may be delisted')
# Exception in thread Thread-152:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-10-31', 'No data found, symbol may be delisted')
# Exception in thread Thread-153:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-04-30', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-154:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2015-01-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-156:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-06-28', 'No data found, symbol may be delisted')
# Exception in thread Thread-155:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2013-12-31', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-157:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-05-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-158:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2008-03-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-159:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2015-05-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-162:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-03-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-161:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-09-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-160:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-11-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-163:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2010-02-26', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-164:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
# ...
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2015-07-31', 'No data found, symbol may be delisted')
# Exception in thread Thread-216:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2014-04-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-217:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2014-09-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-214:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2011-02-28', 'No data found, symbol may be delisted')
# Exception in thread Thread-220:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2014-01-31', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-218:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2009-03-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-221:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2014-12-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-222:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2016-01-29', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-223:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2015-06-30', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-219:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2015-08-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-224:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2012-12-31', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-227:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2008-01-31', 'No data found, symbol may be delisted')
# Exception in thread Thread-225:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2015-02-27', 'No data found, symbol may be delisted')
#
#
# Exception in thread Thread-226:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('2008-06-30', 'No data found, symbol may be delisted')
# [*********************100%***********************]  1 of 112 downloaded
# Empty DataFrame
# Columns: [(2008-01-31, Adj Close), (2008-02-29, Adj Close), (2008-03-31, Adj Close), (2008-04-30, Adj Close), (2008-05-30, Adj Close), (2008-06-30, Adj Close), (2008-07-31, Adj Close), (2008-08-29, Adj Close), (2008-09-30, Adj Close), (2008-10-31, Adj Close), (2008-11-28, Adj Close), (2008-12-31, Adj Close), (2009-01-30, Adj Close), (2009-02-27, Adj Close), (2009-03-31, Adj Close), (2009-04-30, Adj Close), (2009-05-29, Adj Close), (2009-06-30, Adj Close), (2009-07-31, Adj Close), (2009-08-31, Adj Close), (2009-09-30, Adj Close), (2009-10-30, Adj Close), (2009-11-30, Adj Close), (2009-12-31, Adj Close), (2010-01-29, Adj Close), (2010-02-26, Adj Close), (2010-03-31, Adj Close), (2010-04-30, Adj Close), (2010-05-28, Adj Close), (2010-06-30, Adj Close), (2010-07-30, Adj Close), (2010-08-31, Adj Close), (2010-09-30, Adj Close), (2010-10-29, Adj Close), (2010-11-30, Adj Close), (2010-12-31, Adj Close), (2011-01-31, Adj Close), (2011-02-28, Adj Close), (2011-03-31, Adj Close), (2011-04-29, Adj Close), (2011-05-31, Adj Close), (2011-06-30, Adj Close), (2011-07-29, Adj Close), (2011-08-31, Adj Close), (2011-09-30, Adj Close), (2011-10-31, Adj Close), (2011-11-30, Adj Close), (2011-12-30, Adj Close), (2012-01-31, Adj Close), (2012-02-29, Adj Close), (2012-03-30, Adj Close), (2012-04-30, Adj Close), (2012-05-31, Adj Close), (2012-06-29, Adj Close), (2012-07-31, Adj Close), (2012-08-31, Adj Close), (2012-09-28, Adj Close), (2012-10-31, Adj Close), (2012-11-30, Adj Close), (2012-12-31, Adj Close), (2013-01-31, Adj Close), (2013-02-28, Adj Close), (2013-03-28, Adj Close), (2013-04-30, Adj Close), (2013-05-31, Adj Close), (2013-06-28, Adj Close), (2013-07-31, Adj Close), (2013-08-30, Adj Close), (2013-09-30, Adj Close), (2013-10-31, Adj Close), (2013-11-29, Adj Close), (2013-12-31, Adj Close), (2014-01-31, Adj Close), (2014-02-28, Adj Close), (2014-03-31, Adj Close), (2014-04-30, Adj Close), (2014-05-30, Adj Close), (2014-06-30, Adj Close), (2014-07-31, Adj Close), (2014-08-29, Adj Close), (2014-09-30, Adj Close), (2014-10-31, Adj Close), (2014-11-28, Adj Close), (2014-12-31, Adj Close), (2015-01-30, Adj Close), (2015-02-27, Adj Close), (2015-03-31, Adj Close), (2015-04-30, Adj Close), (2015-05-29, Adj Close), (2015-06-30, Adj Close), (2015-07-31, Adj Close), (2015-08-31, Adj Close), (2015-09-30, Adj Close), (2015-10-30, Adj Close), (2015-11-30, Adj Close), (2015-12-31, Adj Close), (2016-01-29, Adj Close), (2016-02-29, Adj Close), (2016-03-31, Adj Close), (2016-04-29, Adj Close), ...]
# Index: []
#
# [0 rows x 672 columns]

# %%
DownloadData(dd, '2007-01-01','2019-08-31','data/')
# Out:
# Exception in thread Thread-231:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('CCWI', 'No data found, symbol may be delisted')
# [                       0%                       ]  2 of 770 downloaded
# Exception in thread Thread-238:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('ESZ', 'No data found for this date range, symbol may be delisted')
# [                       1%                       ]  8 of 770 downloaded
# Exception in thread Thread-247:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('BRIXX', 'No data found for this date range, symbol may be delisted')
# [*                      2%                       ]  17 of 770 downloaded
# Exception in thread Thread-250:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('MXA', 'No data found for this date range, symbol may be delisted')
# [**                     5%                       ]  36 of 770 downloaded
# Exception in thread Thread-271:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('WFM', 'No data found for this date range, symbol may be delisted')
# [***                    6%                       ]  48 of 770 downloaded
# Exception in thread Thread-284:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('CBG', 'No data found for this date range, symbol may be delisted')
# [***                    7%                       ]  51 of 770 downloaded
# Exception in thread Thread-288:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('PGN', 'No data found for this date range, symbol may be delisted')
# [***                    7%                       ]  53 of 770 downloaded
# Exception in thread Thread-293:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('AEC', 'No data found for this date range, symbol may be delisted')
#
# Exception in thread Thread-295:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('NOVL', 'No data found for this date range, symbol may be delisted')
# [****                   8%                       ]  58 of 770 downloaded
# Exception in thread Thread-298:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('RAI', 'No data found for this date range, symbol may be delisted')
#
# Exception in thread Thread-305:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('KFT', 'No data found for this date range, symbol may be delisted')
# [****                   8%                       ]  65 of 770 downloaded
# Exception in thread Thread-307:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('MHFI', 'No data found for this date range, symbol may be delisted')
#
# Exception in thread Thread-310:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('AW', 'No data found for this date range, symbol may be delisted')
# [****                   9%                       ]  69 of 770 downloaded
# Exception in thread Thread-312:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('UNS', 'No data found for this date range, symbol may be delisted')
# [*****                 10%                       ]  75 of 770 downloaded
# Exception in thread Thread-323:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('MTLQQ', 'No data found for this date range, symbol may be delisted')
#
# Exception in thread Thread-324:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('ABKFQ', 'No data found, symbol may be delisted')
# [*****                 10%                       ]  78 of 770 downloaded
# Exception in thread Thread-326:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('PETM', 'No data found for this date range, symbol may be delisted')
# [*****                 11%                       ]  84 of 770 downloaded
# Exception in thread Thread-331:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('HCBK', 'No data found for this date range, symbol may be delisted')
# [******                12%                       ]  96 of 770 downloaded
# Exception in thread Thread-347:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('RSHCQ', 'No data found for this date range, symbol may be delisted')
# [******                13%                       ]  100 of 770 downloaded
# Exception in thread Thread-353:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('CEPH', 'No data found for this date range, symbol may be delisted')
# [*******               14%                       ]  104 of 770 downloaded
# Exception in thread Thread-355:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('ARG', 'No data found for this date range, symbol may be delisted')
# [*******               14%                       ]  110 of 770 downloaded
# Exception in thread Thread-362:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('HRS', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-363:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('VISA', 'No data found, symbol may be delisted')
# [*******               15%                       ]  115 of 770 downloaded
# Exception in thread Thread-369:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('UACC', 'No data found, symbol may be delisted')
#
# Exception in thread Thread-372:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('LVLT', 'No data found for this date range, symbol may be delisted')
#
# Exception in thread Thread-371:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('WYE', 'No data found for this date range, symbol may be delisted')
#
# Exception in thread Thread-373:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('KRFT', 'No data found for this date range, symbol may be delisted')
# [*******               15%                       ]  119 of 770 downloaded
# Exception in thread Thread-374:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('APC', 'No data found, symbol may be delisted')
# [********              16%                       ]  121 of 770 downloaded
# Exception in thread Thread-381:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('KMIWS', 'No data found, symbol may be delisted')
# [********              16%                       ]  127 of 770 downloaded
# Exception in thread Thread-387:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 354, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('OSHSQ', 'No data found, symbol may be delisted')
# [********              17%                       ]  132 of 770 downloaded
# Exception in thread Thread-395:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('FDO', 'No data found for this date range, symbol may be delisted')
# [*********             18%                       ]  141 of 770 downloaded
# Exception in thread Thread-404:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('QWST', 'No data found for this date range, symbol may be delisted')
# [*********             19%                       ]  145 of 770 downloaded
# Exception in thread Thread-405:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('DV', 'No data found for this date range, symbol may be delisted')
# [*********             19%                       ]  149 of 770 downloaded
# Exception in thread Thread-413:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/multitasking/__init__.py", line 102, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 537, in _download_one_threaded
#     period, interval, prepost, proxy, rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 550, in _download_one
#     proxy=proxy, rounding=rounding)
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 366, in history
#     raise ValueError(self.ticker, err_msg)
# ValueError: ('FNP', 'No data found for this date range, symbol may be delisted')
#
# Exception in thread Thread-417:
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 363, in history
#     quotes = self._parse_quotes(data["chart"]["result"][0])
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/site-packages/yfinance/__init__.py", line 208, in _parse_quotes
#     timestamps = data["timestamp"]
# KeyError: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/StevenLiu/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
# ...
# 2007-01-03     22.50     60.36     53.27     34.08     10.42     32.74
# 2007-01-04     22.57     59.91     55.68     34.30     10.65     31.60
# 2007-01-05     22.36     59.19     55.16     33.55     10.57     31.30
# 2007-01-08     22.28     58.62     54.81     33.66     10.62     31.74
# 2007-01-09     22.31     58.70     54.79     33.95     11.51     31.69
# 2007-01-10     22.11     62.22     55.76     34.00     12.06     31.80
# 2007-01-11     22.11     62.71     57.91     34.87     11.91     31.15
# 2007-01-12     22.04     63.37     57.54     34.68     11.76     31.29
# 2007-01-16     22.00     62.94     58.63     34.68     12.07     32.24
# 2007-01-17     21.56     62.83     55.50     34.82     11.80     32.06
# 2007-01-18     21.15     62.36     54.72     35.42     11.07     32.12
# 2007-01-19     21.52     64.62     55.16     35.73     11.00     32.08
# 2007-01-22     21.36     64.15     53.96     35.50     10.79     33.08
# 2007-01-23     21.46     64.97     50.41     35.85     10.65     32.76
# 2007-01-24     21.39     65.45     50.48     36.10     10.78     33.56
# 2007-01-25     21.03     64.77     50.96     35.69     10.72     33.15
# 2007-01-26     21.23     66.00     49.33     35.91     10.61     32.40
# 2007-01-29     20.98     65.45     51.50     35.73     10.68     32.33
# 2007-01-30     20.99     66.50     50.24     35.50     10.63     32.42
# 2007-01-31     20.99     66.83     52.97     36.35     10.66     33.58
# 2007-02-01     21.12     67.86     54.87     35.93     10.53     33.58
# 2007-02-02     20.74     67.12     54.86     35.91     10.53     33.71
# 2007-02-05     20.88     67.37     55.27     35.94     10.43     33.79
# 2007-02-06     20.99     67.97     55.17     36.37     10.46     33.20
# 2007-02-07     21.36     66.52     54.96     36.72     10.71     32.68
# 2007-02-08     21.43     67.53     56.12     37.10     10.71     32.48
# 2007-02-09     21.42     67.28     55.01     36.90     10.35     32.30
# 2007-02-12     21.38     68.07     55.71     35.90     10.55     31.80
# 2007-02-13     21.63     72.41     55.99     35.92     10.53     31.55
# 2007-02-14     21.61     71.53     54.68     35.46     10.60     31.89
# ...              ...       ...       ...       ...       ...       ...
# 2019-07-22     68.94     22.98     32.68    158.84    205.82       NaN
# 2019-07-23     69.74     22.95     33.50    157.58    207.43       NaN
# 2019-07-24     69.43     23.56     34.36    158.44    207.26       NaN
# 2019-07-25     69.70     22.85     31.46    149.97    205.62       NaN
# 2019-07-26     69.35     23.13     31.03    152.56    206.33       NaN
# 2019-07-29     70.22     23.12     30.53    152.98    208.26       NaN
# 2019-07-30     70.00     23.04     30.50    151.74    207.37       NaN
# 2019-07-31     69.26     22.49     30.30    150.58    211.60       NaN
# 2019-08-01     69.06     21.33     29.64    149.89    207.02       NaN
# 2019-08-02     67.93     20.71     29.25    145.72    202.64       NaN
# 2019-08-05     65.72     20.15     28.34    143.10    192.03       NaN
# 2019-08-06     67.51     19.89     28.27    145.58    195.67       NaN
# 2019-08-07     67.82     19.58     28.54    143.98    197.69       NaN
# 2019-08-08     69.34     20.12     28.99    144.37    202.05       NaN
# 2019-08-09     68.49     19.21     28.69    144.27    200.39       NaN
# 2019-08-12     66.49     18.52     27.55    142.10    199.88       NaN
# 2019-08-13     67.49     19.11     27.42    142.17    208.34       NaN
# 2019-08-14     65.45     17.50     26.02    136.44    202.14       NaN
# 2019-08-15     69.44     16.92     25.33    137.45    201.14       NaN
# 2019-08-16     70.93     17.52     25.71    136.54    205.88       NaN
# 2019-08-19     71.60     18.23     26.02    136.30    209.72       NaN
# 2019-08-20     70.97     18.31     25.75    135.33    209.73       NaN
# 2019-08-21     72.04     18.47     26.33    136.18    212.00       NaN
# 2019-08-22     71.59     18.05     26.44    137.45    211.82       NaN
# 2019-08-23     69.40     17.48     25.34    135.00    202.03       NaN
# 2019-08-26     69.49     17.17     25.11    134.95    205.87       NaN
# 2019-08-27     69.33     16.73     24.37    134.84    203.55       NaN
# 2019-08-28     69.79     17.01     25.25    136.71    204.91       NaN
# 2019-08-29     70.55     17.80     26.23    138.02    208.38       NaN
# 2019-08-30     70.96     17.93     26.22    137.90    208.12       NaN
#
#                 ABBV       ABC       ABI     ABKFQ  ...        XRX     XS  \
#            Adj Close Adj Close Adj Close Adj Close  ...     Volume Volume
# 2007-01-03       NaN     18.77       NaN       NaN  ...  1522400.0    NaN
# 2007-01-04       NaN     18.85       NaN       NaN  ...  1106300.0    NaN
# 2007-01-05       NaN     18.62       NaN       NaN  ...   860000.0    NaN
# 2007-01-08       NaN     18.91       NaN       NaN  ...  1921000.0    NaN
# 2007-01-09       NaN     18.85       NaN       NaN  ...  1001600.0    NaN
# 2007-01-10       NaN     18.94       NaN       NaN  ...  1471700.0    NaN
# 2007-01-11       NaN     19.24       NaN       NaN  ...  2295300.0    NaN
# 2007-01-12       NaN     19.29       NaN       NaN  ...  1860000.0    NaN
# 2007-01-16       NaN     19.41       NaN       NaN  ...  1591900.0    NaN
# 2007-01-17       NaN     19.69       NaN       NaN  ...  1016400.0    NaN
# 2007-01-18       NaN     19.58       NaN       NaN  ...  1174300.0    NaN
# 2007-01-19       NaN     19.55       NaN       NaN  ...  1127200.0    NaN
# 2007-01-22       NaN     19.35       NaN       NaN  ...  1201200.0    NaN
# 2007-01-23       NaN     19.57       NaN       NaN  ...  2039900.0    NaN
# 2007-01-24       NaN     21.16       NaN       NaN  ...  1566100.0    NaN
# 2007-01-25       NaN     21.59       NaN       NaN  ...  1358500.0    NaN
# 2007-01-26       NaN     21.51       NaN       NaN  ...  1805700.0    NaN
# 2007-01-29       NaN     21.10       NaN       NaN  ...  1838100.0    NaN
# 2007-01-30       NaN     21.31       NaN       NaN  ...  2222800.0    NaN
# 2007-01-31       NaN     21.33       NaN       NaN  ...  2180900.0    NaN
# 2007-02-01       NaN     21.32       NaN       NaN  ...  1617900.0    NaN
# 2007-02-02       NaN     21.31       NaN       NaN  ...  1489800.0    NaN
# 2007-02-05       NaN     21.38       NaN       NaN  ...  1821000.0    NaN
# 2007-02-06       NaN     21.34       NaN       NaN  ...  1294200.0    NaN
# 2007-02-07       NaN     21.38       NaN       NaN  ...  1480000.0    NaN
# 2007-02-08       NaN     21.45       NaN       NaN  ...  1700700.0    NaN
# 2007-02-09       NaN     21.79       NaN       NaN  ...  1868000.0    NaN
# 2007-02-12       NaN     21.79       NaN       NaN  ...  1244900.0    NaN
# 2007-02-13       NaN     22.03       NaN       NaN  ...  1885200.0    NaN
# 2007-02-14       NaN     21.99       NaN       NaN  ...  2932200.0    NaN
# ...              ...       ...       ...       ...  ...        ...    ...
# 2019-07-22     67.02     84.26       NaN       NaN  ...  1947800.0    NaN
# 2019-07-23     66.76     85.01       NaN       NaN  ...  1429000.0    NaN
# 2019-07-24     66.49     86.08       NaN       NaN  ...  1962700.0    NaN
# 2019-07-25     65.70     85.13       NaN       NaN  ...  2022300.0    NaN
# 2019-07-26     66.79     85.32       NaN       NaN  ...  1442900.0    NaN
# 2019-07-29     66.21     86.42       NaN       NaN  ...  2001800.0    NaN
# 2019-07-30     66.21     87.90       NaN       NaN  ...  5448500.0    NaN
# 2019-07-31     65.66     86.34       NaN       NaN  ...  5865800.0    NaN
# 2019-08-01     64.85     90.85       NaN       NaN  ...  2410400.0    NaN
# 2019-08-02     64.41     89.60       NaN       NaN  ...  3903700.0    NaN
# 2019-08-05     64.29     87.88       NaN       NaN  ...  2761600.0    NaN
# 2019-08-06     63.84     83.33       NaN       NaN  ...  2571200.0    NaN
# 2019-08-07     63.53     85.05       NaN       NaN  ...  2015000.0    NaN
# 2019-08-08     64.51     87.07       NaN       NaN  ...  1818500.0    NaN
# 2019-08-09     64.64     86.64       NaN       NaN  ...  2598600.0    NaN
# 2019-08-12     63.60     86.57       NaN       NaN  ...  2101400.0    NaN
# 2019-08-13     64.08     88.43       NaN       NaN  ...  2068600.0    NaN
# 2019-08-14     62.59     85.54       NaN       NaN  ...  2859600.0    NaN
# 2019-08-15     62.07     85.17       NaN       NaN  ...  2696100.0    NaN
# 2019-08-16     63.50     86.93       NaN       NaN  ...  1504900.0    NaN
# 2019-08-19     65.60     87.34       NaN       NaN  ...  1750500.0    NaN
# 2019-08-20     65.46     85.90       NaN       NaN  ...  1487800.0    NaN
# 2019-08-21     66.57     85.92       NaN       NaN  ...  1588100.0    NaN
# 2019-08-22     66.55     85.15       NaN       NaN  ...  2118600.0    NaN
# 2019-08-23     65.02     83.15       NaN       NaN  ...  2621000.0    NaN
# 2019-08-26     65.50     85.50       NaN       NaN  ...  1604000.0    NaN
# 2019-08-27     64.73     80.90       NaN       NaN  ...  2136400.0    NaN
# 2019-08-28     65.12     80.63       NaN       NaN  ...  2114700.0    NaN
# 2019-08-29     65.27     81.53       NaN       NaN  ...  1505200.0    NaN
# 2019-08-30     64.80     81.89       NaN       NaN  ...  2053600.0    NaN
#
#               XTO        XYL   YHOO         YUM        ZBH       ZION    ZMH  \
#            Volume     Volume Volume      Volume     Volume     Volume Volume
# 2007-01-03    NaN        NaN    NaN   3281300.0  1792400.0   693400.0    NaN
# 2007-01-04    NaN        NaN    NaN   2364900.0  2053000.0   569800.0    NaN
# 2007-01-05    NaN        NaN    NaN   2265900.0  1220400.0   839200.0    NaN
# 2007-01-08    NaN        NaN    NaN   3916700.0  1806100.0   621300.0    NaN
# 2007-01-09    NaN        NaN    NaN   5366100.0  1170900.0   789800.0    NaN
# 2007-01-10    NaN        NaN    NaN   3688300.0   953800.0   578800.0    NaN
# 2007-01-11    NaN        NaN    NaN   3289100.0  1373800.0  1189600.0    NaN
# 2007-01-12    NaN        NaN    NaN   3894800.0  1342600.0   412300.0    NaN
# 2007-01-16    NaN        NaN    NaN   4009900.0  1165300.0   412900.0    NaN
# 2007-01-17    NaN        NaN    NaN   4094200.0  1109000.0   404700.0    NaN
# 2007-01-18    NaN        NaN    NaN   4768900.0  1692900.0   315500.0    NaN
# 2007-01-19    NaN        NaN    NaN   5335500.0  1368500.0   359200.0    NaN
# 2007-01-22    NaN        NaN    NaN   2810300.0  1107900.0   334800.0    NaN
# 2007-01-23    NaN        NaN    NaN   2136000.0   855700.0   379800.0    NaN
# 2007-01-24    NaN        NaN    NaN   2129600.0  1182300.0   515700.0    NaN
# 2007-01-25    NaN        NaN    NaN   4777800.0   804800.0   597800.0    NaN
# 2007-01-26    NaN        NaN    NaN   3123000.0  1662500.0   673400.0    NaN
# 2007-01-29    NaN        NaN    NaN   4480900.0  2455500.0   410800.0    NaN
# 2007-01-30    NaN        NaN    NaN   2514300.0  5420200.0   441900.0    NaN
# 2007-01-31    NaN        NaN    NaN   3042900.0  3631000.0   411800.0    NaN
# 2007-02-01    NaN        NaN    NaN   3658000.0  3347800.0   479800.0    NaN
# 2007-02-02    NaN        NaN    NaN   2628100.0  1418200.0   440000.0    NaN
# 2007-02-05    NaN        NaN    NaN   2436700.0  2581100.0   477700.0    NaN
# 2007-02-06    NaN        NaN    NaN   3004000.0  1776100.0   447500.0    NaN
# 2007-02-07    NaN        NaN    NaN   2894600.0  2158500.0   316800.0    NaN
# 2007-02-08    NaN        NaN    NaN   3422100.0  3163000.0   303200.0    NaN
# 2007-02-09    NaN        NaN    NaN   3195600.0  1409300.0   515800.0    NaN
# 2007-02-12    NaN        NaN    NaN   4344900.0   938400.0   281900.0    NaN
# 2007-02-13    NaN        NaN    NaN  10397400.0  1249400.0   373300.0    NaN
# 2007-02-14    NaN        NaN    NaN   3820700.0  1472900.0   492800.0    NaN
# ...           ...        ...    ...         ...        ...        ...    ...
# 2019-07-22    NaN   731000.0    NaN   1560900.0   529200.0  2792800.0    NaN
# 2019-07-23    NaN   666800.0    NaN   1007100.0   739000.0  7886900.0    NaN
# 2019-07-24    NaN   647200.0    NaN    897500.0  1012900.0  4132000.0    NaN
# 2019-07-25    NaN   720300.0    NaN    882500.0  1692300.0  4082300.0    NaN
# 2019-07-26    NaN   569700.0    NaN    880200.0  5793700.0  3137300.0    NaN
# 2019-07-29    NaN   590900.0    NaN    859400.0  1921700.0  2314400.0    NaN
# 2019-07-30    NaN   579700.0    NaN   1139300.0  1697200.0  1863600.0    NaN
# 2019-07-31    NaN   838900.0    NaN   1686600.0  1448200.0  3208200.0    NaN
# 2019-08-01    NaN  2006600.0    NaN   3406600.0  2176100.0  3149300.0    NaN
# 2019-08-02    NaN   966100.0    NaN   1764400.0  1554900.0  2946700.0    NaN
# 2019-08-05    NaN   872600.0    NaN   1897600.0  1924300.0  3966700.0    NaN
# 2019-08-06    NaN   991700.0    NaN   1643400.0  1023300.0  3297400.0    NaN
# 2019-08-07    NaN   819300.0    NaN   2003000.0  1308800.0  3519600.0    NaN
# 2019-08-08    NaN   880700.0    NaN   2373100.0  1251800.0  2259500.0    NaN
# 2019-08-09    NaN   782100.0    NaN   1656100.0   929600.0  1617700.0    NaN
# 2019-08-12    NaN   720800.0    NaN   1327500.0  1212400.0  2143200.0    NaN
# 2019-08-13    NaN   458600.0    NaN   1502500.0  1143000.0  2474300.0    NaN
# 2019-08-14    NaN   686200.0    NaN   1413200.0  1287100.0  2953300.0    NaN
# 2019-08-15    NaN   674800.0    NaN   1369400.0   924900.0  2818200.0    NaN
# 2019-08-16    NaN   494400.0    NaN   1400900.0   846600.0  2268700.0    NaN
# 2019-08-19    NaN   467000.0    NaN   1061800.0   560600.0  1895700.0    NaN
# 2019-08-20    NaN   513100.0    NaN   1028400.0  1224500.0  2101000.0    NaN
# 2019-08-21    NaN   434100.0    NaN   1065200.0  1112600.0  2475100.0    NaN
# 2019-08-22    NaN   536200.0    NaN    832700.0   673300.0  2197800.0    NaN
# 2019-08-23    NaN  1039900.0    NaN   1800400.0  1278700.0  3474300.0    NaN
# 2019-08-26    NaN   504500.0    NaN   1130300.0   891500.0  2471500.0    NaN
# 2019-08-27    NaN   583200.0    NaN   1380400.0   797900.0  2961200.0    NaN
# 2019-08-28    NaN   352800.0    NaN    879500.0   642700.0  2023200.0    NaN
# 2019-08-29    NaN   850400.0    NaN   1081500.0   979200.0  1797500.0    NaN
# 2019-08-30    NaN   637500.0    NaN   1154200.0  1019400.0  1490800.0    NaN
#
#                   ZTS
#                Volume
# 2007-01-03        NaN
# 2007-01-04        NaN
# 2007-01-05        NaN
# 2007-01-08        NaN
# 2007-01-09        NaN
# 2007-01-10        NaN
# 2007-01-11        NaN
# 2007-01-12        NaN
# 2007-01-16        NaN
# 2007-01-17        NaN
# 2007-01-18        NaN
# 2007-01-19        NaN
# 2007-01-22        NaN
# 2007-01-23        NaN
# 2007-01-24        NaN
# 2007-01-25        NaN
# 2007-01-26        NaN
# 2007-01-29        NaN
# 2007-01-30        NaN
# 2007-01-31        NaN
# 2007-02-01        NaN
# 2007-02-02        NaN
# 2007-02-05        NaN
# 2007-02-06        NaN
# 2007-02-07        NaN
# 2007-02-08        NaN
# 2007-02-09        NaN
# 2007-02-12        NaN
# 2007-02-13        NaN
# 2007-02-14        NaN
# ...               ...
# 2019-07-22  3063400.0
# 2019-07-23  1209600.0
# 2019-07-24  1581200.0
# 2019-07-25  1174500.0
# 2019-07-26  1574100.0
# 2019-07-29  1541500.0
# 2019-07-30  1380800.0
# 2019-07-31  2099800.0
# 2019-08-01  2101200.0
# 2019-08-02  2227000.0
# 2019-08-05  3488100.0
# 2019-08-06  4042200.0
# 2019-08-07  2659000.0
# 2019-08-08  2295000.0
# 2019-08-09  1658000.0
# 2019-08-12  1470300.0
# 2019-08-13  1784700.0
# 2019-08-14  1875200.0
# 2019-08-15  1650300.0
# 2019-08-16  1209700.0
# 2019-08-19  1137000.0
# 2019-08-20  1657100.0
# 2019-08-21  1875000.0
# 2019-08-22  2397900.0
# 2019-08-23  2321400.0
# 2019-08-26  1267400.0
# 2019-08-27  2394900.0
# 2019-08-28  1110400.0
# 2019-08-29  1498800.0
# 2019-08-30  1601200.0
#
# [3194 rows x 4620 columns]
